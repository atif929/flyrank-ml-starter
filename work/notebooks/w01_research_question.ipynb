# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/atif929/flyrank-ml-starter/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## My Lane
#
# I chose **Refresh / Content Opportunity Scoring** because it focuses on identifying which content pages should be reviewed first based on observable search and engagement signals. This builds directly on the work completed in Week 1, where I explored the dataset and compared rule-based scoring with machine learning models. I am interested in learning how data-driven ranking can support better content decisions while keeping the process transparent and easy to explain.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

lane = "Refresh / Content Opportunity Scoring"
print("Selected Lane:", lane)
# Out:
# Selected Lane: Refresh / Content Opportunity Scoring

# %% [markdown]
# ## Research Question
#
# **Decision:** Which content pages should be reviewed first for refresh or improvement?
#
# **Action:** A content or SEO team reviews the highest-ranked pages and decides whether to refresh, expand, optimize, or monitor them.
#
# **Cost of a Wrong Recommendation:** If an unimportant page is recommended, the team wastes time and resources. If an important page is missed, a valuable opportunity to improve search performance may be lost. The goal is to support better prioritization rather than guarantee results.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

decision = "Prioritize pages for content review"
action = "Refresh, improve, or monitor selected pages"
cost = "Wasted effort or missed opportunities"

print("Decision:", decision)
print("Action:", action)
print("Cost:", cost)
# Out:
# Decision: Prioritize pages for content review
# Action: Refresh, improve, or monitor selected pages
# Cost: Wasted effort or missed opportunities

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %% [markdown]
# ## Quick Look at the Data
#
# The starter dataset contains **30,000 content pages** and **44 features**, providing enough information to explore content performance and ranking opportunities. Among these pages, **16,262** are labeled with a **"down"** trend, indicating that a large portion of the dataset represents declining content. This makes the dataset suitable for studying content refresh opportunities and building models that help prioritize which pages should be reviewed first.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

print("Rows:", len(df))
print("Columns:", len(df.columns))
print("Pages with declining trend:", (df["trend_direction"] == "down").sum())
# Out:
# Rows: 30000
# Columns: 44
# Pages with declining trend: 16262

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# ## Careful Words
#
# This project aims to identify observed patterns in search and content performance data to support content review decisions. The results will provide decision-support recommendations based on measurable signals such as impressions, CTR, content age, and trend direction.
#
# However, this work does not prove that refreshing a page will improve rankings or traffic, nor does it predict Google's algorithm. The findings are observational and should be used to assist human decision-making rather than replace it.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

claims = [
    "Observed patterns",
    "Decision-support recommendations",
    "Not causal proof",
    "Cannot predict Google's algorithm"
]

for claim in claims:
    print(claim)
# Out:
# Observed patterns
# Decision-support recommendations
# Not causal proof
# Cannot predict Google's algorithm

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
